# %% [markdown]
# <a href="https://colab.research.google.com/github/rohankodavalla/STM_Bus_Analysis/blob/main/montreal_bus_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas >> /dev/null

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from datetime import datetime
import io
import requests
import zipfile

# %%
# Load Montreal bus data

# URL of the ZIP file (GTFS data)
url = "https://www.stm.info/sites/default/files/gtfs/gtfs_stm.zip"
# Fetched from https://mobilitydatabase.org/feeds/mdb-2126

# Download the ZIP file
response = requests.get(url)
if response.status_code == 200:
    with zipfile.ZipFile(io.BytesIO(response.content)) as z:
        # Extract and read the required CSV files
        files = ["stops.txt", "stop_times.txt", "trips.txt"]
        data = {}  # Dictionary to store DataFrames

        for file in files:
            with z.open(file) as f:
                data[file] = pd.read_csv(f)

    # Assigning DataFrames
    stops = data["stops.txt"]
    stop_times = data["stop_times.txt"]
    trips = data["trips.txt"]

    # Display first few rows of each
    print("Stops Data:")
    print(stops.head())

    print("\nStop Times Data:")
    print(stop_times.head())

    print("\nTrips Data:")
    print(trips.head())

else:
    print("Failed to download the file:", response.status_code)
# Out:
# Stops Data:
#         stop_id  stop_code          stop_name   stop_lat   stop_lon  \
# 0  STATION_M118      10118  STATION ANGRIGNON  45.446466 -73.603118
# 1            43      10118  Station Angrignon  45.446466 -73.603118
# 2         43-01      10118  Station Angrignon  45.446319 -73.603835
# 3  STATION_M120      10120       STATION MONK  45.451158 -73.593242
# 4            42      10120       Station Monk  45.451158 -73.593242
#
#                                             stop_url  location_type  \
# 0                                                NaN              1
# 1  http://www.stm.info/fr/infos/reseaux/metro/ang...              0
# 2                                                NaN              2
# 3                                                NaN              1
# 4    http://www.stm.info/fr/infos/reseaux/metro/monk              0
#
#   parent_station  wheelchair_boarding
# 0            NaN                    1
# 1   STATION_M118                    1
# 2   STATION_M118                    1
# 3            NaN                    2
# 4   STATION_M120                    2
#
# Stop Times Data:
#      trip_id arrival_time departure_time  stop_id  stop_sequence
# 0  280272136     05:13:00       05:13:00    51096              1
# 1  280272136     05:14:51       05:14:51    51140              2
# 2  280272136     05:16:12       05:16:12    51199              3
# 3  280272136     05:17:00       05:17:00    51227              4
# 4  280272136     05:17:15       05:17:15    51266              5
#
# Trips Data:
#    route_id        service_id    trip_id             trip_headsign  \
# 0         1  24N-GLOBAUX-02-S  282976519  Station Honoré-Beaugrand
# 1         1  24N-GLOBAUX-02-S  282976523         Station Angrignon
# 2         1  24N-GLOBAUX-02-S  282976524         Station Angrignon
# 3         1  24N-GLOBAUX-02-S  282976526  Station Honoré-Beaugrand
# 4         1  24N-GLOBAUX-02-S  282976529  Station Honoré-Beaugrand
#
#    direction_id  shape_id  wheelchair_accessible note_fr note_en
# 0             0     11071                      1     NaN     NaN
# 1             1     11072                      1     NaN     NaN
# 2             1     11072                      1     NaN     NaN
# 3             0     11071                      1     NaN     NaN
# 4             0     11071                      1     NaN     NaN

# %%
# ### 2. Data Preprocessing
# Focus on weekday morning/evening peaks

# Ensure consistent data types before merging
stops['stop_id'] = stops['stop_id'].astype(str)
stop_times['stop_id'] = stop_times['stop_id'].astype(str)
trips['trip_id'] = trips['trip_id'].astype(str)
stop_times['trip_id'] = stop_times['trip_id'].astype(str)


# %%
# Merge datasets
df = stop_times.merge(stops, on="stop_id").merge(trips, on="trip_id")

print(df.shape)
# Out:
# (9734422, 21)

# %%
print(df["service_id"].unique()[:10])  # Show first 10 unique service_id values
# Out:
# ['24N-H50N000A-80-A' '24N-H50N000I-80-I' '24N-H50N000S-80-S'
#  '24N-H50N000S-80-SV' '24N-H50N100F-80-F1' '24N-H50N200F-80-F2'
#  '24N-H50N300F-80-F3' '24N-H50N400F-80-F4' '24N-H50NV10A-80-A'
#  '24N-H50NV10I-80-I']

# %%
print(df["service_id"].value_counts().head(20))  # See most common service_id values
# Out:
# service_id
# 25J-H54J000S-80-S    109088
# 25J-H54JV00S-80-S    109088
# 24N-H54N000S-80-S    108872
# 24N-H54NV10S-80-S    108768
# 24N-H54NV20S-80-S    108768
# 25J-H56JV00S-80-S    105509
# 25J-H56J000S-80-S    105509
# 24N-H56N000S-80-S    105122
# 24N-H56NV20S-80-S    105122
# 24N-H56NV10S-81-S    105122
# 24N-H60N000S-81-S     97013
# 24N-H60NV20S-80-S     96469
# 24N-H60NV10S-80-S     96469
# 25J-H60J000S-80-S     96292
# 25J-H58J000S-81-S     95832
# 25J-H60JV00S-80-S     95748
# 24N-H58N000S-80-S     95110
# 25J-H58JV00S-81-S     94932
# 24N-H58NV20S-80-S     94210
# 24N-H58NV10S-80-S     94210
# Name: count, dtype: int64

# %%
# Convert time columns to integers after handling potential errors during conversion
df["departure_time"] = pd.to_datetime(df["departure_time"], format="%H:%M:%S", errors="coerce").dt.hour

# Ensure 'departure_time' is in integer format
df["departure_time"] = df["departure_time"].astype("Int64")

# Now filter for peak hours (07:00-09:00 & 16:00-18:00)
peak_df = df[
    (df["departure_time"].between(7, 9, inclusive="both")) |
    (df["departure_time"].between(16, 18, inclusive="both"))
]

# Verify the shape of the filtered dataframe
print(peak_df.shape)
print(peak_df.head())
# Out:
# (3234244, 21)
#        trip_id arrival_time  departure_time stop_id  stop_sequence  stop_code  \
# 129  280272141     07:01:00               7   56096              7      56096
# 130  280272141     07:01:28               7   56092              8      56092
# 131  280272141     07:02:09               7   56087              9      56087
# 132  280272141     07:02:58               7   56084             10      56084
# 133  280272141     07:04:04               7   56132             11      56132
#
#              stop_name   stop_lat   stop_lon  \
# 129  Graham / Rockland  45.520412 -73.629331
# 130   Graham / Trenton  45.519875 -73.631147
# 131    Graham / Simcoe  45.519101 -73.633759
# 132    Graham / Dunrae  45.518192 -73.636836
# 133    Graham / Regent  45.516947 -73.641045
#
#                                         stop_url  ...  parent_station  \
# 129  https://www.stm.info/fr/recherche#stq=56096  ...             NaN
# 130  https://www.stm.info/fr/recherche#stq=56092  ...             NaN
# 131  https://www.stm.info/fr/recherche#stq=56087  ...             NaN
# 132  https://www.stm.info/fr/recherche#stq=56084  ...             NaN
# 133  https://www.stm.info/fr/recherche#stq=56132  ...             NaN
#
#     wheelchair_boarding  route_id         service_id trip_headsign  \
# 129                   1        16  24N-H50N000A-80-A         Ouest
# 130                   1        16  24N-H50N000A-80-A         Ouest
# 131                   1        16  24N-H50N000A-80-A         Ouest
# 132                   1        16  24N-H50N000A-80-A         Ouest
# 133                   1        16  24N-H50N000A-80-A         Ouest
#
#     direction_id  shape_id  wheelchair_accessible  note_fr note_en
# 129            1    160088                      1      NaN     NaN
# 130            1    160088                      1      NaN     NaN
# 131            1    160088                      1      NaN     NaN
# 132            1    160088                      1      NaN     NaN
# 133            1    160088                      1      NaN     NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # Error was found prev, so this is  something I learnt, and changed code accordingly
# *This error occurs because the stop_id column has different data types in stop_times and stops. One is int64, and the other is an object (likely a string).*
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c3f32a8368fd> in <cell line: 0>()
#       4 # %%
#       5 # Merge datasets
# ----> 6 df = stop_times.merge(stops, on="stop_id").merge(trips, on="trip_id")
#       7
#       8 # Convert time columns, handling potential values over 24:00:00
#
# 3 frames
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1506                     inferred_right in string_types and inferred_left not in string_types
#    1507                 ):
# -> 1508                     raise ValueError(msg)
#    1509
#    1510             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns for key 'stop_id'. If you wish to proceed you should use pd.concat

# %%
print(df['service_id'].unique())  # See available service_id values
# Out:
# ['24N-H50N000A-80-A' '24N-H50N000I-80-I' '24N-H50N000S-80-S'
#  '24N-H50N000S-80-SV' '24N-H50N100F-80-F1' '24N-H50N200F-80-F2'
#  '24N-H50N300F-80-F3' '24N-H50N400F-80-F4' '24N-H50NV10A-80-A'
#  '24N-H50NV10I-80-I' '24N-H50NV10S-81-S' '24N-H50NV10S-81-SV'
#  '24N-H50NV20A-80-A' '24N-H50NV20I-80-I' '24N-H50NV20S-80-S'
#  '24N-H50NV20S-80-SV' '24N-H54N000A-80-A' '24N-H54N000I-80-I'
#  '24N-H54N000S-80-S' '24N-H54N100F-80-F1' '24N-H54N200F-80-F2'
#  '24N-H54N300F-80-F3' '24N-H54N400F-80-F4' '24N-H54NV10A-80-A'
#  '24N-H54NV10I-80-I' '24N-H54NV10S-80-S' '24N-H54NV20A-80-A'
#  '24N-H54NV20I-80-I' '24N-H54NV20S-80-S' '24N-H55N000A-80-A'
#  '24N-H55N000I-80-I' '24N-H55N000S-80-S' '24N-H55N000S-80-SV'
#  '24N-H55N100F-80-F1' '24N-H55N200F-80-F2' '24N-H55N300F-80-F3'
#  '24N-H55N400F-80-F4' '24N-H55NV10A-80-A' '24N-H55NV10I-80-I'
#  '24N-H55NV10S-83-S' '24N-H55NV10S-83-SV' '24N-H55NV20A-80-A'
#  '24N-H55NV20I-80-I' '24N-H55NV20S-80-S' '24N-H55NV20S-80-SV'
#  '24N-H56N000A-80-A' '24N-H56N000I-80-I' '24N-H56N000S-80-S'
#  '24N-H56N000S-80-SV' '24N-H56N100F-80-F1' '24N-H56N200F-80-F2'
#  '24N-H56N300F-80-F3' '24N-H56N400F-80-F4' '24N-H56NV10A-80-A'
#  '24N-H56NV10I-80-I' '24N-H56NV10S-81-S' '24N-H56NV10S-81-SV'
#  '24N-H56NV20A-80-A' '24N-H56NV20I-80-I' '24N-H56NV20S-80-S'
#  '24N-H56NV20S-80-SV' '24N-H57N000A-80-A' '24N-H57N000I-80-I'
#  '24N-H57N000S-80-S' '24N-H57N100F-80-F1' '24N-H57N200F-80-F2'
#  '24N-H57N20I-80-I' '24N-H57N300F-80-F3' '24N-H57N400F-80-F4'
#  '24N-H57NV10A-80-A' '24N-H57NV10I-80-I' '24N-H57NV10S-81-S'
#  '24N-H57NV20A-80-A' '24N-H57NV20S-80-S' '24N-H58N000A-80-A'
#  '24N-H58N000I-80-I' '24N-H58N000S-80-S' '24N-H58N100F-80-F1'
#  '24N-H58N200F-80-F2' '24N-H58N300F-81-F3' '24N-H58N400F-80-F4'
#  '24N-H58NV10A-80-A' '24N-H58NV10I-80-I' '24N-H58NV10S-80-S'
#  '24N-H58NV20A-80-A' '24N-H58NV20I-80-I' '24N-H58NV20S-80-S'
#  '24N-H59N000A-80-A' '24N-H59N000I-80-I' '24N-H59N000S-80-S'
#  '24N-H59N000S-80-SV' '24N-H59N100F-80-F1' '24N-H59N200F-80-F2'
#  '24N-H59N300F-80-F3' '24N-H59N400F-80-F4' '24N-H59NV10A-80-A'
#  '24N-H59NV10I-80-I' '24N-H59NV10S-83-S' '24N-H59NV10S-83-SV'
#  '24N-H59NV20A-80-A' '24N-H59NV20I-80-I' '24N-H59NV20S-80-S'
#  '24N-H59NV20S-80-SV' '24N-H60N000A-80-A' '24N-H60N000I-80-I'
#  '24N-H60N000S-81-S' '24N-H60N100F-80-F1' '24N-H60N200F-80-F2'
#  '24N-H60N300F-80-F3' '24N-H60N400F-81-F4' '24N-H60NV10A-80-A'
#  '24N-H60NV10I-80-I' '24N-H60NV10S-80-S' '24N-H60NV20A-80-A'
#  '24N-H60NV20I-80-I' '24N-H60NV20S-80-S' '24N-H62N000A-80-A'
#  '24N-H62N000I-80-I' '24N-H62N000S-80-S' '24N-H62N100F-80-F1'
#  '24N-H62N200F-80-F2' '24N-H62N300F-80-F3' '24N-H62N400F-80-F4'
#  '24N-H62NV10A-80-A' '24N-H62NV10I-80-I' '24N-H62NV10S-80-S'
#  '24N-H62NV20A-80-A' '24N-H62NV20I-80-I' '24N-H62NV20S-80-S'
#  '25J-H50J000A-80-A' '25J-H50J000I-80-I' '25J-H50J000S-80-S'
#  '25J-H50J000S-80-SV' '25J-H50JV00A-80-A' '25J-H50JV00I-80-I'
#  '25J-H50JV00S-81-S' '25J-H50JV00S-81-SV' '25J-H54J000A-80-A'
#  '25J-H54J000I-80-I' '25J-H54J000S-80-S' '25J-H54JV00A-80-A'
#  '25J-H54JV00I-80-I' '25J-H54JV00S-80-S' '25J-H55J000A-83-A'
#  '25J-H55J000I-80-I' '25J-H55J000S-81-S' '25J-H55J000S-81-SV'
#  '25J-H55JV00A-80-A' '25J-H55JV00I-80-I' '25J-H55JV00S-80-S'
#  '25J-H55JV00S-80-SV' '25J-H56J000A-81-A' '25J-H56J000I-81-I'
#  '25J-H56J000S-80-S' '25J-H56J000S-80-SV' '25J-H56JV00A-80-A'
#  '25J-H56JV00I-80-I' '25J-H56JV00S-80-S' '25J-H56JV00S-80-SV'
#  '25J-H57J000A-80-A' '25J-H57J000I-81-I' '25J-H57J000S-83-S'
#  '25J-H57JV00A-80-A' '25J-H57JV00I-80-I' '25J-H57JV00S-84-S'
#  '25J-H58J000A-81-A' '25J-H58J000I-80-I' '25J-H58J000S-81-S'
#  '25J-H58JV00A-80-A' '25J-H58JV00I-80-I' '25J-H58JV00S-81-S'
#  '25J-H59J000A-80-A' '25J-H59J000I-80-I' '25J-H59J000S-80-S'
#  '25J-H59J000S-80-SV' '25J-H59JV00A-80-A' '25J-H59JV00I-80-I'
#  '25J-H59JV00S-83-S' '25J-H59JV00S-83-SV' '25J-H60J000A-80-A'
#  '25J-H60J000I-80-I' '25J-H60J000S-80-S' '25J-H60JV00A-80-A'
#  '25J-H60JV00I-80-I' '25J-H60JV00S-80-S' '25J-H62J000A-80-A'
#  '25J-H62J000I-80-I' '25J-H62J000S-80-S' '25J-H62JV00A-80-A'
#  '25J-H62JV00I-80-I' '25J-H62JV00S-80-S' '24N-GLOBAUX-02-S'
#  '24N-GLOBAUX-06-S' '24N-GLOBAUX-01-A' '24N-GLOBAUX-01-I'
#  '24N-GLOBAUX-02-F1' '24N-GLOBAUX-01-F2' '24N-GLOBAUX-01-F3'
#  '24N-GLOBAUX-01-F4' '25J-GLOBAUX-02-S' '25J-GLOBAUX-01-A'
#  '25J-GLOBAUX-22-A' '25J-GLOBAUX-01-I']

# %% [markdown]
# # filtering trips based on peak departure times (07:00-09:00 & 16:00-18:00)

# %%
# ### 3. Spatial Analysis
# Identify busiest stops during peaks

# %%
# Aggregate departures by stop
stop_activity = (
    peak_df.groupby(["stop_id", "stop_name", "stop_lat", "stop_lon"])
    .size()
    .reset_index(name="departures")
    .sort_values("departures", ascending=False)
)

# Top 10 busiest stops
print("🏙️ Busiest Transit Hubs:")
display(stop_activity.head(10).style.background_gradient(cmap="Reds"))
# Out:
# 🏙️ Busiest Transit Hubs:
# <style type="text/css">
# #T_21c79_row0_col2 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_21c79_row0_col3 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_21c79_row0_col4, #T_21c79_row2_col2, #T_21c79_row2_col3, #T_21c79_row3_col2, #T_21c79_row3_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_21c79_row1_col2 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_21c79_row1_col3 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_21c79_row1_col4 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_21c79_row2_col4 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_21c79_row3_col4 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_21c79_row4_col2 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_21c79_row4_col3 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_21c79_row4_col4 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_21c79_row5_col2, #T_21c79_row6_col3, #T_21c79_row9_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_21c79_row5_col3 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_21c79_row5_col4 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_21c79_row6_col2 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_21c79_row6_col4 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_21c79_row7_col2 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_21c79_row7_col3 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_21c79_row7_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_21c79_row8_col2 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_21c79_row8_col3 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_21c79_row8_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_21c79_row9_col2 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_21c79_row9_col3 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# </style>
# <table id="T_21c79" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21c79_level0_col0" class="col_heading level0 col0" >stop_id</th>
#       <th id="T_21c79_level0_col1" class="col_heading level0 col1" >stop_name</th>
#       <th id="T_21c79_level0_col2" class="col_heading level0 col2" >stop_lat</th>
#       <th id="T_21c79_level0_col3" class="col_heading level0 col3" >stop_lon</th>
#       <th id="T_21c79_level0_col4" class="col_heading level0 col4" >departures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c79_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_21c79_row0_col0" class="data row0 col0" >36</td>
#       <td id="T_21c79_row0_col1" class="data row0 col1" >Station Lionel-Groulx</td>
#       <td id="T_21c79_row0_col2" class="data row0 col2" >45.482509</td>
#       <td id="T_21c79_row0_col3" class="data row0 col3" >-73.580180</td>
#       <td id="T_21c79_row0_col4" class="data row0 col4" >2850</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row1" class="row_heading level0 row1" >3619</th>
#       <td id="T_21c79_row1_col0" class="data row1 col0" >54127</td>
#       <td id="T_21c79_row1_col1" class="data row1 col1" >Station Henri-Bourassa</td>
#       <td id="T_21c79_row1_col2" class="data row1 col2" >45.556117</td>
#       <td id="T_21c79_row1_col3" class="data row1 col3" >-73.667282</td>
#       <td id="T_21c79_row1_col4" class="data row1 col4" >2176</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row2" class="row_heading level0 row2" >2897</th>
#       <td id="T_21c79_row2_col0" class="data row2 col0" >53287</td>
#       <td id="T_21c79_row2_col1" class="data row2 col1" >Sherbrooke / Saint-Donat</td>
#       <td id="T_21c79_row2_col2" class="data row2 col2" >45.601134</td>
#       <td id="T_21c79_row2_col3" class="data row2 col3" >-73.532423</td>
#       <td id="T_21c79_row2_col4" class="data row2 col4" >1940</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row3" class="row_heading level0 row3" >2899</th>
#       <td id="T_21c79_row3_col0" class="data row3 col0" >53289</td>
#       <td id="T_21c79_row3_col1" class="data row3 col1" >Sherbrooke / Saint-Donat</td>
#       <td id="T_21c79_row3_col2" class="data row3 col2" >45.600830</td>
#       <td id="T_21c79_row3_col3" class="data row3 col3" >-73.532279</td>
#       <td id="T_21c79_row3_col4" class="data row3 col4" >1840</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row4" class="row_heading level0 row4" >4419</th>
#       <td id="T_21c79_row4_col0" class="data row4 col0" >55073</td>
#       <td id="T_21c79_row4_col1" class="data row4 col1" >Henri-Bourassa / Pelletier</td>
#       <td id="T_21c79_row4_col2" class="data row4 col2" >45.598390</td>
#       <td id="T_21c79_row4_col3" class="data row4 col3" >-73.640215</td>
#       <td id="T_21c79_row4_col4" class="data row4 col4" >1828</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row5" class="row_heading level0 row5" >7902</th>
#       <td id="T_21c79_row5_col0" class="data row5 col0" >60633</td>
#       <td id="T_21c79_row5_col1" class="data row5 col1" >Angrignon / face aux tours Angrignon</td>
#       <td id="T_21c79_row5_col2" class="data row5 col2" >45.446925</td>
#       <td id="T_21c79_row5_col3" class="data row5 col3" >-73.607584</td>
#       <td id="T_21c79_row5_col4" class="data row5 col4" >1796</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row6" class="row_heading level0 row6" >4906</th>
#       <td id="T_21c79_row6_col0" class="data row6 col0" >55594</td>
#       <td id="T_21c79_row6_col1" class="data row6 col1" >Côte-Vertu / Leduc</td>
#       <td id="T_21c79_row6_col2" class="data row6 col2" >45.510803</td>
#       <td id="T_21c79_row6_col3" class="data row6 col3" >-73.687253</td>
#       <td id="T_21c79_row6_col4" class="data row6 col4" >1721</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row7" class="row_heading level0 row7" >643</th>
#       <td id="T_21c79_row7_col0" class="data row7 col0" >50747</td>
#       <td id="T_21c79_row7_col1" class="data row7 col1" >Sherbrooke / Patricia</td>
#       <td id="T_21c79_row7_col2" class="data row7 col2" >45.455402</td>
#       <td id="T_21c79_row7_col3" class="data row7 col3" >-73.641252</td>
#       <td id="T_21c79_row7_col4" class="data row7 col4" >1703</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row8" class="row_heading level0 row8" >236</th>
#       <td id="T_21c79_row8_col0" class="data row8 col0" >50303</td>
#       <td id="T_21c79_row8_col1" class="data row8 col1" >Station Henri-Bourassa</td>
#       <td id="T_21c79_row8_col2" class="data row8 col2" >45.554262</td>
#       <td id="T_21c79_row8_col3" class="data row8 col3" >-73.668563</td>
#       <td id="T_21c79_row8_col4" class="data row8 col4" >1696</td>
#     </tr>
#     <tr>
#       <th id="T_21c79_level0_row9" class="row_heading level0 row9" >281</th>
#       <td id="T_21c79_row9_col0" class="data row9 col0" >50351</td>
#       <td id="T_21c79_row9_col1" class="data row9 col1" >Henri-Bourassa / Christophe-Colomb</td>
#       <td id="T_21c79_row9_col2" class="data row9 col2" >45.562444</td>
#       <td id="T_21c79_row9_col3" class="data row9 col3" >-73.662481</td>
#       <td id="T_21c79_row9_col4" class="data row9 col4" >1640</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Percentage of Stops Handling Peak Departures

# %%
# Calculate total departures in peak hours
total_peak_departures = peak_df.shape[0]

# Calculate the percentage of total departures handled by top stops
top_stops = stop_activity.head(10)
top_stop_departures = top_stops['departures'].sum()
percent_top_stop_departures = (top_stop_departures / total_peak_departures) * 100

print(f"Top 10 stops handle {percent_top_stop_departures:.2f}% of peak departures")
# Out:
# Top 10 stops handle 0.59% of peak departures

# %% [markdown]
# # PM Peak vs. AM Peak
# If the PM peak has more departures than the AM peak, extending the PM peak service window can help balance congestion.

# %%
# ### 4. Temporal Analysis
# Compare AM vs PM peak demand

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=peak_df, x='departure_time', y='departure_time',
            estimator='count', ci=None, palette='viridis')
plt.title("🚌 Hourly Departure Distribution", fontsize=14)
plt.xlabel("Hour of Day", fontsize=12)
plt.ylabel("Number of Departures", fontsize=12)
plt.axvspan(6.5, 9.5, alpha=0.1, color='blue', label='AM Peak')
plt.axvspan(15.5, 18.5, alpha=0.1, color='orange', label='PM Peak')
plt.legend()
plt.show()
# Out:
# <ipython-input-15-a2f14deac9dc>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=peak_df, x='departure_time', y='departure_time',
# <ipython-input-15-a2f14deac9dc>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=peak_df, x='departure_time', y='departure_time',
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128652 (\N{BUS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Calculate AM and PM peak departures
am_peak = peak_df[peak_df['departure_time'].between(7, 9, inclusive="both")]
pm_peak = peak_df[peak_df['departure_time'].between(16, 18, inclusive="both")]

am_departures = am_peak.shape[0]
pm_departures = pm_peak.shape[0]

# Compare the PM peak departures to AM peak
pm_am_difference = (pm_departures - am_departures) / am_departures * 100

print(f"PM peak has {pm_am_difference:.2f}% more departures than AM peak")

# If PM peak has more departures, suggest extending service window
if pm_am_difference > 0:
    print(f"Extend PM peak service window by {int(pm_am_difference)} minutes.")
# Out:
# PM peak has 18.38% more departures than AM peak
# Extend PM peak service window by 18 minutes.

# %%
# ### 5. Geographic Visualization
# Map demand hotspots

# %%
# Convert to GeoDataFrame
geometry = gpd.points_from_xy(stop_activity.stop_lon, stop_activity.stop_lat)
gdf = gpd.GeoDataFrame(stop_activity, geometry=geometry)

# Load Montreal boroughs
montreal = gpd.read_file("https://donnees.montreal.ca/en/dataset/limites-administratives-agglomeration/resource/e18bfd07-edc8-4ce8-8a5a-3b617662a794/download")

# Create figure
fig, ax = plt.subplots(figsize=(15,10))
montreal.plot(ax=ax, alpha=0.3, edgecolor='black')
gdf.plot(ax=ax, markersize=gdf['departures']/50,
         alpha=0.6, color='red', label='Departure Frequency')
plt.title("🔥 Montreal Bus Demand Heatmap (Peak Hours)", fontsize=16)
plt.axis('off')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import numpy as np

# Convert to GeoDataFrame
geometry = gpd.points_from_xy(stop_activity.stop_lon, stop_activity.stop_lat)
gdf = gpd.GeoDataFrame(stop_activity, geometry=geometry)

# Load Montreal boroughs
montreal = gpd.read_file("https://donnees.montreal.ca/en/dataset/limites-administratives-agglomeration/resource/e18bfd07-edc8-4ce8-8a5a-3b617662a794/download")

# Normalize departure values for colormap
min_dep, max_dep = gdf['departures'].min(), gdf['departures'].max()
gdf['normalized_dep'] = (gdf['departures'] - min_dep) / (max_dep - min_dep)

# Create figure
fig, ax = plt.subplots(figsize=(15, 10))
montreal.plot(ax=ax, alpha=0.3, edgecolor='black')

# Scatter plot with color gradient
sc = ax.scatter(
    gdf.geometry.x, gdf.geometry.y,
    s=gdf['departures'] / 50,  # Adjust size based on departures
    c=gdf['normalized_dep'],  # Use normalized departures for color mapping
    cmap='YlOrRd',  # Yellow → Orange → Red
    alpha=0.8, edgecolor='black'
)

plt.title("🔥 Montreal Bus Demand Heatmap (Peak Hours)", fontsize=16)
plt.axis('off')

# Add colorbar
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Departure Frequency', fontsize=12)

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #Heatmap: Busiest Hours of the Week and Top 10 Busiest Stops

# %%
#Heatmap: Busiest Hours of the Week

# Count trips per hour per day
hourly_counts = df.groupby(["day_of_week", "hour"]).size().reset_index(name="trip_count")

# Create pivot table
pivot_table = hourly_counts.pivot(index="hour", columns="day_of_week", values="trip_count")

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, cmap="Blues", annot=True, fmt="g")
plt.xlabel("Day of the Week (0=Monday, 6=Sunday)")
plt.ylabel("Hour of the Day")
plt.title("<<<<< Scheduled Departures per Hour by Day >>>>>>")
plt.show()

import calendar

# Map numbers (0-6) to day names
day_labels = [calendar.day_name[i] for i in range(7)]

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, cmap="Blues", annot=True, fmt="g")

# Update x-axis labels
plt.xticks(ticks=range(7), labels=day_labels, rotation=45)

plt.xlabel("Day of the Week")
plt.ylabel("Hour of the Day")
plt.title("📊 Scheduled Departures per Hour by Day")
plt.show()


#Find Top 10 Busiest Stops


busiest_stops = peak_df["stop_name"].value_counts().reset_index()
busiest_stops.columns = ["stop_name", "trip_count"]

print("<<<<<<< Top 10 Busiest Stops >>>>>>>")
print(busiest_stops.head(10))
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <<<<<<< Top 10 Busiest Stops >>>>>>>
#                   stop_name  trip_count
# 0    Station Henri-Bourassa       10114
# 1        Station Côte-Vertu        6812
# 2         Station Angrignon        6794
# 3     Station Lionel-Groulx        5571
# 4         Terminus Fairview        5191
# 5           Station Vendôme        5096
# 6  Station Honoré-Beaugrand        4654
# 7        Station Berri-UQAM        4520
# 8           Terminus Dorval        4237
# 9  Sherbrooke / Saint-Donat        3780
